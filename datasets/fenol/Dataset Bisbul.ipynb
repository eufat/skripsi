# %%
from scipy.io import loadmat
import pandas as pd
import os

# %%
data = loadmat('Dataset_Baru.mat')

# %%
head = ['397.66',
 '400.28',
 '402.9',
 '405.52',
 '408.13',
 '410.75',
 '413.37',
 '416',
 '418.62',
 '421.24',
 '423.86',
 '426.49',
 '429.12',
 '431.74',
 '434.37',
 '437',
 '439.63',
 '442.26',
 '444.89',
 '447.52',
 '450.16',
 '452.79',
 '455.43',
 '458.06',
 '460.7',
 '463.34',
 '465.98',
 '468.62',
 '471.26',
 '473.9',
 '476.54',
 '479.18',
 '481.83',
 '484.47',
 '487.12',
 '489.77',
 '492.42',
 '495.07',
 '497.72',
 '500.37',
 '503.02',
 '505.67',
 '508.32',
 '510.98',
 '513.63',
 '516.29',
 '518.95',
 '521.61',
 '524.27',
 '526.93',
 '529.59',
 '532.25',
 '534.91',
 '537.57',
 '540.24',
 '542.91',
 '545.57',
 '548.24',
 '550.91',
 '553.58',
 '556.25',
 '558.92',
 '561.59',
 '564.26',
 '566.94',
 '569.61',
 '572.29',
 '574.96',
 '577.64',
 '580.32',
 '583',
 '585.68',
 '588.36',
 '591.04',
 '593.73',
 '596.41',
 '599.1',
 '601.78',
 '604.47',
 '607.16',
 '609.85',
 '612.53',
 '615.23',
 '617.92',
 '620.61',
 '623.3',
 '626',
 '628.69',
 '631.39',
 '634.08',
 '636.78',
 '639.48',
 '642.18',
 '644.88',
 '647.58',
 '650.29',
 '652.99',
 '655.69',
 '658.4',
 '661.1',
 '663.81',
 '666.52',
 '669.23',
 '671.94',
 '674.65',
 '677.36',
 '680.07',
 '682.79',
 '685.5',
 '688.22',
 '690.93',
 '693.65',
 '696.37',
 '699.09',
 '701.81',
 '704.53',
 '707.25',
 '709.97',
 '712.7',
 '715.42',
 '718.15',
 '720.87',
 '723.6',
 '726.33',
 '729.06',
 '731.79',
 '734.52',
 '737.25',
 '739.98',
 '742.72',
 '745.45',
 '748.19',
 '750.93',
 '753.66',
 '756.4',
 '759.14',
 '761.88',
 '764.62',
 '767.36',
 '770.11',
 '772.85',
 '775.6',
 '778.34',
 '781.09',
 '783.84',
 '786.58',
 '789.33',
 '792.08',
 '794.84',
 '797.59',
 '800.34',
 '803.1',
 '805.85',
 '808.61',
 '811.36',
 '814.12',
 '816.88',
 '819.64',
 '822.4',
 '825.16',
 '827.92',
 '830.69',
 '833.45',
 '836.22',
 '838.98',
 '841.75',
 '844.52',
 '847.29',
 '850.06',
 '852.83',
 '855.6',
 '858.37',
 '861.14',
 '863.92',
 '866.69',
 '869.47',
 '872.25',
 '875.03',
 '877.8',
 '880.58',
 '883.37',
 '886.15',
 '888.93',
 '891.71',
 '894.5',
 '897.28',
 '900.07',
 '902.86',
 '905.64',
 '908.43',
 '911.22',
 '914.02',
 '916.81',
 '919.6',
 '922.39',
 '925.19',
 '927.98',
 '930.78',
 '933.58',
 '936.38',
 '939.18',
 '941.98',
 '944.78',
 '947.58',
 '950.38',
 '953.19',
 '955.99',
 '958.8',
 '961.6',
 '964.41',
 '967.22',
 '970.03',
 '972.84',
 '975.65',
 '978.46',
 '981.27',
 '984.09',
 '986.9',
 '989.72',
 '992.54',
 '995.35',
 '998.17',
 '1000.99',
 '1003.81']

# %%
reflectance = pd.DataFrame(data['cropReflectance'])
klorofil_a = pd.read_csv('Data_Kadar/Batch 1/9 crop/Klorofil A.csv',names=['Klorofil A'])
klorofil_b = pd.read_csv('Data_Kadar/Batch 1/9 crop/Klorofil B.csv',names=['Klorofil B'])
karotenoid = pd.read_csv('Data_Kadar/Batch 1/9 crop/Karotenoid.csv',names=['Karotenoid'])
flavo = pd.read_csv('Data_Kadar/Batch 1/9 crop/Flavonoid.csv',names=['Flavonoid'])
fenol = pd.read_csv('Data_Kadar/Batch 1/9 crop/Fenolik.csv',names=['Fenolik'])

dataframe = pd.concat([reflectance, klorofil_a, klorofil_b, karotenoid, flavo, fenol], axis=1)
dataframe.columns = head

# %%
dataframe.head()
# Out:
#      397.66    400.28     402.9    405.52    408.13    410.75    413.37  \
# 0  1.051904  1.004678  0.933635  0.878269  0.827133  0.769639  0.721070
# 1  1.050614  0.978409  0.943560  0.883855  0.843708  0.746743  0.726893
# 2  1.112291  0.987403  0.906112  0.877525  0.845253  0.777860  0.742769
# 3  1.071519  0.976688  0.929321  0.875486  0.811788  0.737282  0.703827
# 4  1.112733  0.974468  0.947926  0.877950  0.812468  0.744000  0.695606
#
#         416    418.62    421.24    ...       992.54    995.35    998.17  \
# 0  0.669046  0.621854  0.597337    ...     0.942047  0.938973  0.939384
# 1  0.649541  0.623086  0.583483    ...     0.948875  0.945111  0.952885
# 2  0.673440  0.649355  0.613195    ...     0.963552  0.965341  0.964505
# 3  0.640114  0.616061  0.567978    ...     0.951751  0.951296  0.948010
# 4  0.635883  0.598492  0.547428    ...     0.961502  0.958833  0.962055
#
#     1000.99   1003.81  Klorofil A  Klorofil B  Karotenoid   Flavonoid  \
# ...

# %%
dataframe.to_csv('Batch 1/Dataset_Batch_1_Crop9.csv',index=False)

# %%
pd.read_csv('Batch 1/Dataset_Batch_1_Crop9.csv').head()
# Out:
#      397.66    400.28     402.9    405.52    408.13    410.75    413.37  \
# 0  1.051904  1.004678  0.933635  0.878269  0.827133  0.769639  0.721070
# 1  1.050614  0.978409  0.943560  0.883855  0.843708  0.746743  0.726893
# 2  1.112291  0.987403  0.906112  0.877525  0.845253  0.777860  0.742769
# 3  1.071519  0.976688  0.929321  0.875486  0.811788  0.737282  0.703827
# 4  1.112733  0.974468  0.947926  0.877950  0.812468  0.744000  0.695606
#
#         416    418.62    421.24    ...       992.54    995.35    998.17  \
# 0  0.669046  0.621854  0.597337    ...     0.942047  0.938973  0.939384
# 1  0.649541  0.623086  0.583483    ...     0.948875  0.945111  0.952885
# 2  0.673440  0.649355  0.613195    ...     0.963552  0.965341  0.964505
# 3  0.640114  0.616061  0.567978    ...     0.951751  0.951296  0.948010
# 4  0.635883  0.598492  0.547428    ...     0.961502  0.958833  0.962055
#
#     1000.99   1003.81  Klorofil A  Klorofil B  Karotenoid   Flavonoid  \
# ...

# %%
dataframe.shape
# Out:
# (486, 229)

# %%
refl = pd.DataFrame(data['cropReflectance'])
refl.columns = head

# abs735 = pd.read_csv('Data_Kadar/Absorbansi_735_Batch_1_Crop_9.csv', names=['Absorbansi 735 nm'])
# gabung = pd.concat([refl, abs735], axis=1)

# %%
refl.shape
# Out:
# (738, 224)

# %%
refl.to_csv('Reflectance_Baru.csv', index=False)

# %%
pd.read_csv('Reflectance_Baru.csv').head()
# Out:
#      397.66    400.28     402.9    405.52    408.13    410.75    413.37  \
# 0  1.071888  0.972967  0.927259  0.859528  0.814563  0.732133  0.705139
# 1  1.098594  0.972958  0.915506  0.869775  0.816965  0.743328  0.700581
# 2  1.107632  0.992840  0.943511  0.872657  0.826729  0.741778  0.702973
# 3  1.090357  0.987339  0.933168  0.857207  0.813601  0.746898  0.707530
# 4  1.111850  0.977303  0.935073  0.881331  0.820806  0.751077  0.704687
#
#         416    418.62    421.24    ...       978.46    981.27    984.09  \
# 0  0.639593  0.612300  0.577846    ...     0.941629  0.944192  0.943166
# 1  0.646832  0.618049  0.575018    ...     0.948633  0.953284  0.949595
# 2  0.648001  0.607790  0.564421    ...     0.952110  0.954838  0.955897
# 3  0.649270  0.603117  0.556855    ...     0.948159  0.948010  0.948768
# 4  0.657196  0.604151  0.562535    ...     0.956081  0.958448  0.957239
#
#       986.9    989.72    992.54    995.35    998.17   1000.99   1003.81
# ...

# %%
new = pd.read_csv('Reflectance_Baru.csv')
kadar = pd.read_csv('Data_Kadar/Absorbansi_735_Fixed.csv', names=['Absorbansi 735 nm'])
kadar.shape
# Out:
# (738, 1)

# %%
gabung = pd.concat([new, kadar], axis=1)
gabung.tail()
# Out:
#        397.66    400.28     402.9    405.52    408.13    410.75    413.37  \
# 733  0.861596  0.836311  0.824480  0.775368  0.715200  0.668315  0.615399
# 734  0.867708  0.843394  0.824300  0.786842  0.725295  0.664129  0.627941
# 735  0.880302  0.839950  0.812495  0.768467  0.723399  0.673798  0.611051
# 736  0.867053  0.830154  0.804251  0.776669  0.719903  0.667366  0.616502
# 737  0.858015  0.827495  0.818270  0.784672  0.724689  0.662576  0.621409
#
#           416    418.62    421.24        ...            981.27    984.09  \
# 733  0.583986  0.544388  0.493985        ...          0.823661  0.822750
# 734  0.588172  0.546909  0.492608        ...          0.831159  0.832082
# 735  0.573169  0.544143  0.498233        ...          0.824720  0.826583
# 736  0.576395  0.535752  0.491694        ...          0.823475  0.824279
# 737  0.582563  0.538272  0.492531        ...          0.829120  0.831107
#
#         986.9    989.72    992.54    995.35    998.17   1000.99   1003.81  \
# ...

# %%
gabung.to_csv('Dataset_Baru.csv', index=False)

# %%
pd.read_csv('Dataset_Baru.csv')
# Out:
#        397.66    400.28     402.9    405.52    408.13    410.75    413.37  \
# 0    1.071888  0.972967  0.927259  0.859528  0.814563  0.732133  0.705139
# 1    1.098594  0.972958  0.915506  0.869775  0.816965  0.743328  0.700581
# 2    1.107632  0.992840  0.943511  0.872657  0.826729  0.741778  0.702973
# 3    1.090357  0.987339  0.933168  0.857207  0.813601  0.746898  0.707530
# 4    1.111850  0.977303  0.935073  0.881331  0.820806  0.751077  0.704687
# 5    1.096250  0.995847  0.928938  0.862286  0.820059  0.746285  0.708858
# 6    1.134000  0.984439  0.941936  0.887396  0.833377  0.761995  0.705485
# 7    1.104966  0.976681  0.922736  0.872549  0.816827  0.754131  0.712310
# 8    1.080454  0.972845  0.927795  0.860765  0.817106  0.735135  0.702919
# 9    1.018623  0.958743  0.928964  0.866069  0.839082  0.773380  0.721965
# 10   1.017913  0.952068  0.920630  0.857024  0.836379  0.775045  0.722065
# 11   1.010699  0.952222  0.912737  0.860953  0.845063  0.778954  0.731876
# ...
